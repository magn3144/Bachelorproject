# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Create a directory for packages
# !mkdir -p "/content/drive/My Drive/DTU/7. Semester/Bachelorproject/packages"

# Install a package to the directory
# !pip install --target="/content/drive/My Drive/Colab Notebooks/packages" autotrain-advanced huggingface_hub

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Add the directory to sys.path
import sys
sys.path.append("/content/drive/My Drive/Colab Notebooks/packages")

# !pip install autotrain-advanced
# !pip install huggingface_hub

# !autotrain setup --update-torch

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !autotrain llm\
--train\
--project_name\
LLAMA_2_Sentiment\
--model TinyPixel/Llama-2-7B-bf16-sharded\
--data_path AdiOO7/Llama-2\
--use_peft\
--use_int4\
--learning_rate 2e-4\
--train_batch_size 2\
--num_train_epochs 1\
--trainer sft\
--model_max_length 2048\
--push_to_hub\
--repo_id magnus42/LLAMA2-Sentiment
